# %% [markdown]
# ## 화요일 파이썬데이터분석 202084052 김아현,  201984056 장세희

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 데이터 불러오기

# %%
df= pd.read_csv("C:\\Users\\kim a hyun\\Desktop\\사고다발지현황.csv",encoding='cp949')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##  데이터 정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2038 entries, 0 to 2037
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시군명          2035 non-null   object
#  1   사고년도         2038 non-null   int64
#  2   사고유형구분       2038 non-null   object
#  3   다발지식별자       2038 non-null   int64
#  4   다발지역그룹식별자    2038 non-null   int64
#  5   법정동코드        2038 non-null   int64
#  6   위치코드         2038 non-null   int64
#  7   시도시군구명       2038 non-null   object
#  8   사고지역위치명      2038 non-null   object
#  9   발생건수         2038 non-null   int64
#  10  사상자수         2038 non-null   int64
#  11  사망자수         2038 non-null   int64
#  12  중상자수         2038 non-null   int64
#  13  경상자수         2038 non-null   int64
#  14  부상자수         2038 non-null   int64
#  15  위도           2038 non-null   float64
#  16  경도           2038 non-null   float64
#  17  사고다발지역폴리곤정보  2038 non-null   object
# ...

# %%
df.head(3)
# Out:
#    시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드    시도시군구명  \
# 0  가평군  2018  보행노인사고다발지  6506068    2019036  4182032521   41820001  경기도 가평군1
# 1  가평군  2017  무단횡단사고다발지  6430775    2018045  4182025023  281141002    경기 가평2
# 2  가평군  2017  무단횡단사고다발지  6429445    2018045  4182032521  281141001    경기 가평1
#
#                        사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수         위도  \
# 0        경기도 가평군 청평면(청평터미널 부근)     4     4     0     2     2     0  37.739333
# 1  경기도 가평군 가평읍(가평군농협 자라섬지점 부근)     3     3     2     1     0     0  37.814267
# 2         경기도 가평군 청평면(종로약국 부근)     4     4     0     0     1     3  37.737294
#
#            경도                                        사고다발지역폴리곤정보
# 0  127.421720  {"type":"Polygon","coordinates":[[[127.4235169...
# 1  127.514815  {"type":"Polygon","coordinates":[[[127.5175100...
# 2  127.418783  {"type":"Polygon","coordinates":[[[127.4214779...

# %%
df.tail(3) #끝에 3개 확인
# Out:
#       시군명  사고년도      사고유형구분  다발지식별자  다발지역그룹식별자       법정동코드      위치코드  \
# 2035  NaN  2013   보행노인사고다발지  196836    2014105  4173025000  41730001
# 2036  NaN  2013   보행노인사고다발지  196837    2014105  4173031021  41730002
# 2037  NaN  2013  보행어린이사고다발지  198405    2014110  4173025022  41730001
#
#         시도시군구명                사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 2035  경기도 여주군1  경기도 여주군 여주읍(홍문사거리 부근)     5     5     0     5     0     0
# 2036  경기도 여주군2  경기도 여주군 점동면(점동중학교 인근)     3     3     1     1     0     1
# 2037  경기도 여주군1  경기도 여주군 여주읍(홍문사거리 부근)     3     3     0     1     2     0
#
#              위도          경도                                        사고다발지역폴리곤정보
# 2035  37.296606  127.636983  {"type":"Polygon","coordinates":[[[127.6385775...
# 2036  37.206433  127.662428  {"type":"Polygon","coordinates":[[[127.6640215...
# 2037  37.295550  127.637564  {"type":"Polygon","coordinates":[[[127.6391594...

# %%
df.isna().sum() #결측치 확인/ 시군명 결측치확인
# Out:
# 시군명            3
# 사고년도           0
# 사고유형구분         0
# 다발지식별자         0
# 다발지역그룹식별자      0
# 법정동코드          0
# 위치코드           0
# 시도시군구명         0
# 사고지역위치명        0
# 발생건수           0
# 사상자수           0
# 사망자수           0
# 중상자수           0
# 경상자수           0
# 부상자수           0
# 위도             0
# 경도             0
# 사고다발지역폴리곤정보    0
# dtype: int64

# %%
df.shape  #행,열
# Out:
# (2038, 18)

# %%
len(df)   #길이
# Out:
# 2038

# %%
df.describe().T #기술통계
# Out:
#             count          mean           std           min           25%  \
# 사고년도       2038.0  2.015321e+03  2.500318e+00  2.012000e+03  2.013000e+03
# 다발지식별자     2038.0  4.668698e+06  2.732236e+06  9.952700e+04  2.203222e+05
# 다발지역그룹식별자  2038.0  2.016394e+06  2.471812e+03  2.013060e+06  2.014110e+06
# 법정동코드      2038.0  4.114529e+09  2.397119e+08  4.111313e+07  4.115010e+09
# 위치코드       2038.0  9.610212e+07  1.267791e+08  4.111100e+07  4.117300e+07
# 발생건수       2038.0  4.661433e+00  2.036533e+00  1.000000e+00  3.000000e+00
# 사상자수       2038.0  4.909715e+00  2.195567e+00  1.000000e+00  4.000000e+00
# 사망자수       2038.0  2.266928e-01  4.960660e-01  0.000000e+00  0.000000e+00
# 중상자수       2038.0  2.332188e+00  1.723115e+00  0.000000e+00  1.000000e+00
# 경상자수       2038.0  2.010304e+00  1.541885e+00  0.000000e+00  1.000000e+00
# 부상자수       2038.0  3.405299e-01  6.481241e-01  0.000000e+00  0.000000e+00
# 위도         2038.0  3.743400e+01  1.999886e-01  3.696905e+01  3.729660e+01
# ...

# %%
columns=df.columns  #열을 추출
pd.Series(columns)
# Out:
# 0             시군명
# 1            사고년도
# 2          사고유형구분
# 3          다발지식별자
# 4       다발지역그룹식별자
# 5           법정동코드
# 6            위치코드
# 7          시도시군구명
# 8         사고지역위치명
# 9            발생건수
# 10           사상자수
# 11           사망자수
# 12           중상자수
# 13           경상자수
# 14           부상자수
# 15             위도
# 16             경도
# 17    사고다발지역폴리곤정보
# dtype: object

# %%
data=df.to_numpy()
data
# Out:
# array([['가평군', 2018, '보행노인사고다발지', ..., 37.73933318, 127.4217204,
# ...

# %%
#행이 몇개 있는지 확인(
index = df.index
index
# Out:
# RangeIndex(start=0, stop=2038, step=1)

# %%
df.dtypes
# Out:
# 시군명             object
# 사고년도             int64
# 사고유형구분          object
# 다발지식별자           int64
# 다발지역그룹식별자        int64
# 법정동코드            int64
# 위치코드             int64
# 시도시군구명          object
# 사고지역위치명         object
# 발생건수             int64
# 사상자수             int64
# 사망자수             int64
# 중상자수             int64
# 경상자수             int64
# 부상자수             int64
# 위도             float64
# 경도             float64
# 사고다발지역폴리곤정보     object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      11
# object      5
# float64     2
# dtype: int64

# %%
df.head(1)
# Out:
#    시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드      위치코드    시도시군구명  \
# 0  가평군  2018  보행노인사고다발지  6506068    2019036  4182032521  41820001  경기도 가평군1
#
#                  사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수         위도  \
# 0  경기도 가평군 청평면(청평터미널 부근)     4     4     0     2     2     0  37.739333
#
#           경도                                        사고다발지역폴리곤정보
# 0  127.42172  {"type":"Polygon","coordinates":[[[127.4235169...

# %% [markdown]
# ## 필요없는 열 삭제

# %%
df=df.drop(columns=['다발지식별자','다발지역그룹식별자','법정동코드','위치코드','사고다발지역폴리곤정보'])

# %%
df.head(1)
# Out:
#    시군명  사고년도     사고유형구분    시도시군구명                사고지역위치명  발생건수  사상자수  사망자수  \
# 0  가평군  2018  보행노인사고다발지  경기도 가평군1  경기도 가평군 청평면(청평터미널 부근)     4     4     0
#
#    중상자수  경상자수  부상자수         위도         경도
# 0     2     2     0  37.739333  127.42172

# %%
np.iinfo(64)
# Out:
# iinfo(min=-2147483648, max=2147483647, dtype=int32)

# %%
df.tail(5) # 결측치 내용 확인
# Out:
#       시군명  사고년도      사고유형구분    시도시군구명                       사고지역위치명  발생건수  \
# 2033  화성시  2012   무단횡단사고다발지  경기 화성동부5  경기도 화성시 진안동((디지털프라자앞교차로) 부근)     5
# 2034  화성시  2012  보행어린이사고다발지  경기도 화성시1    경기도 화성시 능동((서해그랑블앞교차로) 부근)     4
# 2035  NaN  2013   보행노인사고다발지  경기도 여주군1         경기도 여주군 여주읍(홍문사거리 부근)     5
# 2036  NaN  2013   보행노인사고다발지  경기도 여주군2         경기도 여주군 점동면(점동중학교 인근)     3
# 2037  NaN  2013  보행어린이사고다발지  경기도 여주군1         경기도 여주군 여주읍(홍문사거리 부근)     3
#
#       사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도
# 2033     5     1     3     1     0  37.211550  127.036314
# 2034     4     0     3     1     0  37.198866  127.072021
# 2035     5     0     5     0     0  37.296606  127.636983
# 2036     3     1     1     0     1  37.206433  127.662428
# 2037     3     0     1     2     0  37.295550  127.637564

# %%
df=df.fillna('여주시')

# %%
df.isna().sum()
# Out:
# 시군명        0
# 사고년도       0
# 사고유형구분     0
# 시도시군구명     0
# 사고지역위치명    0
# 발생건수       0
# 사상자수       0
# 사망자수       0
# 중상자수       0
# 경상자수       0
# 부상자수       0
# 위도         0
# 경도         0
# dtype: int64

# %%
df.tail(4)
# Out:
#       시군명  사고년도      사고유형구분    시도시군구명                     사고지역위치명  발생건수  사상자수  \
# 2034  화성시  2012  보행어린이사고다발지  경기도 화성시1  경기도 화성시 능동((서해그랑블앞교차로) 부근)     4     4
# 2035  여주시  2013   보행노인사고다발지  경기도 여주군1       경기도 여주군 여주읍(홍문사거리 부근)     5     5
# 2036  여주시  2013   보행노인사고다발지  경기도 여주군2       경기도 여주군 점동면(점동중학교 인근)     3     3
# 2037  여주시  2013  보행어린이사고다발지  경기도 여주군1       경기도 여주군 여주읍(홍문사거리 부근)     3     3
#
#       사망자수  중상자수  경상자수  부상자수         위도          경도
# 2034     0     3     1     0  37.198866  127.072021
# 2035     0     5     0     0  37.296606  127.636983
# 2036     1     1     0     1  37.206433  127.662428
# 2037     0     1     2     0  37.295550  127.637564

# %% [markdown]
# ## 데이터 이름 바꿔주기

# %%
df['사고유형구분'].drop_duplicates().value_counts() #자전?-> 자전거사고다발지로/ 보행노->보행노인사고다발지로 변경해야됨
# Out:
# 보행노인사고다발지       1
# 무단횡단사고다발지       1
# 자전거사고다발지        1
# 보행노             1
# 자전?             1
# 보행어린이사고다발지      1
# 스쿨존내어린이사고다발지    1
# Name: 사고유형구분, dtype: int64

# %% [markdown]
# #### 자전?-> 자전거사고다발지로/ 보행노->보행노인사고다발지로 데이터 이름 변경

# %%
df.loc[df['사고유형구분'] == '자전?', '사고유형구분'] = '자전거사고다발지'
df
# Out:
#       시군명  사고년도      사고유형구분    시도시군구명                        사고지역위치명  발생건수  \
# 0     가평군  2018   보행노인사고다발지  경기도 가평군1          경기도 가평군 청평면(청평터미널 부근)     4
# 1     가평군  2017   무단횡단사고다발지    경기 가평2    경기도 가평군 가평읍(가평군농협 자라섬지점 부근)     3
# 2     가평군  2017   무단횡단사고다발지    경기 가평1           경기도 가평군 청평면(종로약국 부근)     4
# 3     가평군  2017   보행노인사고다발지  경기도 가평군1  경기도 가평군 가평읍(가평군농협하나로마트자라점 부근)     3
# 4     가평군  2016    자전거사고다발지  경기도 가평군1           경기도 가평군 청평면(중감천교 부근)     4
# ...   ...   ...         ...       ...                            ...   ...
# 2033  화성시  2012   무단횡단사고다발지  경기 화성동부5   경기도 화성시 진안동((디지털프라자앞교차로) 부근)     5
# 2034  화성시  2012  보행어린이사고다발지  경기도 화성시1     경기도 화성시 능동((서해그랑블앞교차로) 부근)     4
# 2035  여주시  2013   보행노인사고다발지  경기도 여주군1          경기도 여주군 여주읍(홍문사거리 부근)     5
# 2036  여주시  2013   보행노인사고다발지  경기도 여주군2          경기도 여주군 점동면(점동중학교 인근)     3
# 2037  여주시  2013  보행어린이사고다발지  경기도 여주군1          경기도 여주군 여주읍(홍문사거리 부근)     3
#
#       사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도
# ...

# %%
df.loc[df['사고유형구분'] == '보행노', '사고유형구분'] = '보행노인사고다발지'
df
# Out:
#       시군명  사고년도      사고유형구분    시도시군구명                        사고지역위치명  발생건수  \
# 0     가평군  2018   보행노인사고다발지  경기도 가평군1          경기도 가평군 청평면(청평터미널 부근)     4
# 1     가평군  2017   무단횡단사고다발지    경기 가평2    경기도 가평군 가평읍(가평군농협 자라섬지점 부근)     3
# 2     가평군  2017   무단횡단사고다발지    경기 가평1           경기도 가평군 청평면(종로약국 부근)     4
# 3     가평군  2017   보행노인사고다발지  경기도 가평군1  경기도 가평군 가평읍(가평군농협하나로마트자라점 부근)     3
# 4     가평군  2016    자전거사고다발지  경기도 가평군1           경기도 가평군 청평면(중감천교 부근)     4
# ...   ...   ...         ...       ...                            ...   ...
# 2033  화성시  2012   무단횡단사고다발지  경기 화성동부5   경기도 화성시 진안동((디지털프라자앞교차로) 부근)     5
# 2034  화성시  2012  보행어린이사고다발지  경기도 화성시1     경기도 화성시 능동((서해그랑블앞교차로) 부근)     4
# 2035  여주시  2013   보행노인사고다발지  경기도 여주군1          경기도 여주군 여주읍(홍문사거리 부근)     5
# 2036  여주시  2013   보행노인사고다발지  경기도 여주군2          경기도 여주군 점동면(점동중학교 인근)     3
# 2037  여주시  2013  보행어린이사고다발지  경기도 여주군1          경기도 여주군 여주읍(홍문사거리 부근)     3
#
#       사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도
# ...

# %% [markdown]
# #### 데이터 결측치 변경(fillna)/이름 변경(loc)/필요없는 열 삭제(drop) 완료

# %% [markdown]
# ## 데이터 변환(memory_usage 이용)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2038 entries, 0 to 2037
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시군명      2038 non-null   object
#  1   사고년도     2038 non-null   int64
#  2   사고유형구분   2038 non-null   object
#  3   시도시군구명   2038 non-null   object
#  4   사고지역위치명  2038 non-null   object
#  5   발생건수     2038 non-null   int64
#  6   사상자수     2038 non-null   int64
#  7   사망자수     2038 non-null   int64
#  8   중상자수     2038 non-null   int64
#  9   경상자수     2038 non-null   int64
#  10  부상자수     2038 non-null   int64
#  11  위도       2038 non-null   float64
#  12  경도       2038 non-null   float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 207.1+ KB

# %%
df.dtypes
# Out:
# 시군명         object
# 사고년도         int64
# 사고유형구분      object
# 시도시군구명      object
# 사고지역위치명     object
# 발생건수         int64
# 사상자수         int64
# 사망자수         int64
# 중상자수         int64
# 경상자수         int64
# 부상자수         int64
# 위도         float64
# 경도         float64
# dtype: object

# %%
df.memory_usage(deep=True)
# Out:
# Index         128
# 시군명        179736
# 사고년도        16304
# 사고유형구분     203200
# 시도시군구명     207458
# 사고지역위치명    269622
# 발생건수        16304
# 사상자수        16304
# 사망자수        16304
# 중상자수        16304
# 경상자수        16304
# 부상자수        16304
# 위도          16304
# 경도          16304
# dtype: int64

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
df['시군명'] = df['시군명'].astype('object')
df.memory_usage(deep=True)
# Out:
# Index         128
# 시군명        179736
# 사고년도        16304
# 사고유형구분     203200
# 시도시군구명     207458
# 사고지역위치명    269622
# 발생건수        16304
# 사상자수        16304
# 사망자수        16304
# 중상자수        16304
# 경상자수        16304
# 부상자수        16304
# 위도          16304
# 경도          16304
# dtype: int64

# %%
df.describe().T
# Out:
#        count         mean       std          min          25%          50%  \
# 사고년도  2038.0  2015.321394  2.500318  2012.000000  2013.000000  2015.000000
# 발생건수  2038.0     4.661433  2.036533     1.000000     3.000000     4.000000
# 사상자수  2038.0     4.909715  2.195567     1.000000     4.000000     4.000000
# 사망자수  2038.0     0.226693  0.496066     0.000000     0.000000     0.000000
# 중상자수  2038.0     2.332188  1.723115     0.000000     1.000000     2.000000
# 경상자수  2038.0     2.010304  1.541885     0.000000     1.000000     2.000000
# 부상자수  2038.0     0.340530  0.648124     0.000000     0.000000     0.000000
# 위도    2038.0    37.433995  0.199989    36.969045    37.296596    37.403916
# 경도    2038.0   126.984869  0.173202   126.598540   126.824471   127.003320
#
#               75%          max
# 사고년도  2017.000000  2020.000000
# 발생건수     5.000000    26.000000
# 사상자수     6.000000    26.000000
# 사망자수     0.000000     4.000000
# 중상자수     3.000000    22.000000
# ...

# %%
np.iinfo('int16')
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
df = pd.read_csv("C:\\Users\\kim a hyun\\Desktop\\사고다발지현황.csv",encoding='cp949', nrows=1000,
           dtype={
               '사고년도': np.int32,
               '다발지역그룹식별자': np.int32,
               '발생건수': np.int32,
               '사상자수': np.int32,
               '사망자수': np.int32,
               '중상자수': np.int32,
               '경상자수': np.int32,
               '부상자수': np.int32,
               '위도':np.float32,
               '경도':np.float32
               
           })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시군명          1000 non-null   object
#  1   사고년도         1000 non-null   int32
#  2   사고유형구분       1000 non-null   object
#  3   다발지식별자       1000 non-null   int64
#  4   다발지역그룹식별자    1000 non-null   int32
#  5   법정동코드        1000 non-null   int64
#  6   위치코드         1000 non-null   int64
#  7   시도시군구명       1000 non-null   object
#  8   사고지역위치명      1000 non-null   object
#  9   발생건수         1000 non-null   int32
#  10  사상자수         1000 non-null   int32
#  11  사망자수         1000 non-null   int32
#  12  중상자수         1000 non-null   int32
#  13  경상자수         1000 non-null   int32
#  14  부상자수         1000 non-null   int32
#  15  위도           1000 non-null   float32
#  16  경도           1000 non-null   float32
#  17  사고다발지역폴리곤정보  1000 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시군명          1000 non-null   object
#  1   사고년도         1000 non-null   int32
#  2   사고유형구분       1000 non-null   object
#  3   다발지식별자       1000 non-null   int64
#  4   다발지역그룹식별자    1000 non-null   int32
#  5   법정동코드        1000 non-null   int64
#  6   위치코드         1000 non-null   int64
#  7   시도시군구명       1000 non-null   object
#  8   사고지역위치명      1000 non-null   object
#  9   발생건수         1000 non-null   int32
#  10  사상자수         1000 non-null   int32
#  11  사망자수         1000 non-null   int32
#  12  중상자수         1000 non-null   int32
#  13  경상자수         1000 non-null   int32
#  14  부상자수         1000 non-null   int32
#  15  위도           1000 non-null   float32
#  16  경도           1000 non-null   float32
#  17  사고다발지역폴리곤정보  1000 non-null   object
# ...

# %% [markdown]
# ## EDA

# %%
df['시군명'].drop_duplicates().value_counts().sum() #총 31개 지역
# Out:
# 13

# %%
df['사고유형구분'].drop_duplicates().value_counts() #사고유형구분 5개
# Out:
# 보행노인사고다발지       1
# 무단횡단사고다발지       1
# 자전거사고다발지        1
# 보행노             1
# 자전?             1
# 보행어린이사고다발지      1
# 스쿨존내어린이사고다발지    1
# Name: 사고유형구분, dtype: int64

# %%
df['시군명'].value_counts() #수원시에서 가장 많은 사고가 일어남
# Out:
# 수원시     191
# 성남시     169
# 부천시     162
# 고양시     156
# 남양주시     77
# 광명시      57
# 군포시      43
# 구리시      36
# 김포시      35
# 광주시      32
# 동두천시     24
# 가평군      10
# 과천시       8
# Name: 시군명, dtype: int64

# %%
df['사고년도'].value_counts() #년도별 2012년이 가장 많이 나옴, 사고는 점점 줄어드는 추세
# Out:
# 2015    156
# 2012    150
# 2014    136
# 2016    125
# 2013    109
# 2018     97
# 2017     94
# 2020     71
# 2019     62
# Name: 사고년도, dtype: int64

# %% [markdown]
# ### 최대(nlargest) 이용

# %%
df.nlargest(100,'발생건수').head(10) #사고발생건수가 가장 많은 유형은 무단횡단사고
                                     #발생건수가 가장 많이 나타난 시는 수원시/26개
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 939  수원시  2015  무단횡단사고다발지  6223108    2016152  4111513400   41115001
# 682  성남시  2017  보행노인사고다발지  6401906    2018029  4113110300   41131001
# 145  고양시  2012  무단횡단사고다발지   167060    2013114  4128510500  411334008
# 531  부천시  2015   자전거사고다발지  6223300    2016147  4119510800   41195001
# 578  부천시  2013  무단횡단사고다발지   220261    2014117  4119710400  411323001
# 732  성남시  2015   자전거사고다발지  6223725    2016147  4113310100   41133001
# 506  부천시  2015  무단횡단사고다발지  6223109    2016152  4119910400   41199001
# 576  부천시  2013  무단횡단사고다발지   220377    2014117  4119710200  411323002
# 777  성남시  2012  무단횡단사고다발지   167488    2013114  4113310100  411332005
# 789  성남시  2012  무단횡단사고다발지   167073    2013114  4113110200  411308010
#
#            시도시군구명                         사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 939  경기도 수원시 팔달구1  경기도 수원시 팔달구 매산로1가(수원역동측단일로 부근)    20    20     2    12
# ...

# %%
df.nlargest(100,'사상자수').head(10) #사상자수가 가장 많이 나타난 시는 수원시/26명
                                     #사상자수가 가장 많은 유형은 무단횡단사고
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 939  수원시  2015  무단횡단사고다발지  6223108    2016152  4111513400   41115001
# 682  성남시  2017  보행노인사고다발지  6401906    2018029  4113110300   41131001
# 789  성남시  2012  무단횡단사고다발지   167073    2013114  4113110200  411308010
# 145  고양시  2012  무단횡단사고다발지   167060    2013114  4128510500  411334008
# 578  부천시  2013  무단횡단사고다발지   220261    2014117  4119710400  411323001
# 756  성남시  2013  무단횡단사고다발지   220244    2014117  4113110300  411308001
# 531  부천시  2015   자전거사고다발지  6223300    2016147  4119510800   41195001
# 576  부천시  2013  무단횡단사고다발지   220377    2014117  4119710200  411323002
# 681  성남시  2017  보행노인사고다발지  6401907    2018029  4113110600   41131002
# 732  성남시  2015   자전거사고다발지  6223725    2016147  4113310100   41133001
#
#            시도시군구명                          사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 939  경기도 수원시 팔달구1   경기도 수원시 팔달구 매산로1가(수원역동측단일로 부근)    20    20     2    12
# ...

# %%
df.nlargest(100,'사망자수').head(10) # 사망자수가 많이 나타난 시는 시흥시/4명
                                     #무단횡단사고다발지 발생
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 1    가평군  2017  무단횡단사고다발지  6430775    2018045  4182025023  281141002
# 3    가평군  2017  보행노인사고다발지  6402864    2018029  4182025023   41820001
# 71   고양시  2016  보행노인사고다발지  6243368    2017029  4128110600   41281002
# 73   고양시  2016  보행노인사고다발지  6250559    2017029  4128510600   41285002
# 99   고양시  2014  무단횡단사고다발지  6103557    2015052  4128110600  132141001
# 125  고양시  2013  무단횡단사고다발지   220381    2014117  4128710200  411334001
# 157  고양시  2012  보행노인사고다발지   149471    2013098  4128710200   41287002
# 223  광명시  2012  무단횡단사고다발지   167417    2013114  4121010100  411327002
# 295  구리시  2012  무단횡단사고다발지   167486    2013114  4131010500  411337007
# 376  김포시  2012  무단횡단사고다발지   167115    2013114  4157010100  411318006
#
#             시도시군구명                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 1           경기 가평2        경기도 가평군 가평읍(가평군농협 자라섬지점 부근)     3     3     2     1
# ...

# %%
df.nlargest(100,'경상자수').head(10) #경상자수가 많이 나타난 시는 성남시/10명
                                     #사고유형은 무단행단사고다발지에서 나타남
                                     #전체적으로 여러곳에서 여러가지 유형의 사고가 나타남
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 756  성남시  2013  무단횡단사고다발지   220244    2014117  4113110300  411308001
# 792  성남시  2012  무단횡단사고다발지   167467    2013114  4113310100  411332003
# 911  수원시  2016  보행노인사고다발지  6249910    2017029  4111113400   41111001
# 98   고양시  2015   자전거사고다발지  6223401    2016147  4128710400   41287001
# 210  광명시  2014  보행노인사고다발지  6099996    2015048  4121010100   41210001
# 518  부천시  2015  보행노인사고다발지  6222631    2016146  4119710100   41197002
# 629  부천시  2012   자전거사고다발지   160339    2013099  4119510800   41195009
# 732  성남시  2015   자전거사고다발지  6223725    2016147  4113310100   41133001
# 48   고양시  2018   자전거사고다발지  6516170    2019038  4128510500   41285001
# 110  고양시  2014   자전거사고다발지  6097078    2015046  4128112300   41281001
#
#             시도시군구명                          사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 756       경기 성남수정1        경기도 성남시 수정구 수진동(모란사거리 부근)    10    14     2     2
# ...

# %%
df.nlargest(100,'부상자수').head(10) #부상자수가 많이 나타난 시는 광명시/4명
                                     #사고유형은 자전거사고다발지에서 나타남
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 205  광명시  2015   자전거사고다발지  6223728    2016147  4121010100   41210002
# 533  부천시  2015   자전거사고다발지  6223524    2016147  4119510900   41195003
# 2    가평군  2017  무단횡단사고다발지  6429445    2018045  4182032521  281141001
# 32   고양시  2019   자전거사고다발지  6619223    2020037  4128510600   41285001
# 111  고양시  2014   자전거사고다발지  6097367    2015046  4128710100   41287003
# 185  광명시  2018   자전거사고다발지  6515845    2019038  4121010100   41210002
# 197  광명시  2016   자전거사고다발지  6303021    2017050  4121010100   41210001
# 301  군포시  2020        자전?  6689629    2021028  4141010400   41410001
# 527  부천시  2015   자전거사고다발지  6223347    2016147  4119510900   41195020
# 531  부천시  2015   자전거사고다발지  6223300    2016147  4119510800   41195001
#
#             시도시군구명                         사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 205       경기도 광명시2           경기도 광명시 광명동(광명사거리 부근)     7     7     0     0
# ...

# %%
df.nlargest(100,'중상자수').head(10) #중상자수가 많이 나타난 시는 수원시/22명
                                     #무단횡단사고다발지에서 발생
# Out:
#      시군명  사고년도     사고유형구분   다발지식별자  다발지역그룹식별자       법정동코드       위치코드  \
# 789  성남시  2012  무단횡단사고다발지   167073    2013114  4113110200  411308010
# 939  수원시  2015  무단횡단사고다발지  6223108    2016152  4111513400   41115001
# 145  고양시  2012  무단횡단사고다발지   167060    2013114  4128510500  411334008
# 755  성남시  2013  무단횡단사고다발지   220213    2014117  4113310400  411332001
# 153  고양시  2012  무단횡단사고다발지   167494    2013114  4128510400  411334007
# 155  고양시  2012  보행노인사고다발지   149468    2013098  4128510500   41285001
# 215  광명시  2013  무단횡단사고다발지   220411    2014117  4121010100  411327001
# 508  부천시  2015  무단횡단사고다발지  6223026    2016152  4119510900   41195001
# 682  성남시  2017  보행노인사고다발지  6401906    2018029  4113110300   41131001
# 723  성남시  2015  보행노인사고다발지  6222664    2016146  4113110300   41131001
#
#             시도시군구명                         사고지역위치명  발생건수  사상자수  사망자수  중상자수  \
# 789      경기 성남수정10     경기도 성남시 수정구 태평동(예일병원사거리 부근)    12    15     0    12
# ...

# %% [markdown]
# #### 대체로 무단횡단에서 많은 사람들이 다치는것으로 확인.

# %% [markdown]
# ### sort_values이용

# %%
#사고유형을 기준으로 정렬해보기
(
    df[['사고년도','사고유형구분','시도시군구명','발생건수']]
.sort_values('사고유형구분',ascending=True)
)
# Out:
#      사고년도     사고유형구분         시도시군구명  발생건수
# 779  2012  무단횡단사고다발지       경기 성남수정1     4
# 442  2012  무단횡단사고다발지        경기 남양주2     4
# 436  2013  무단횡단사고다발지        경기 남양주2     4
# 435  2013  무단횡단사고다발지        경기 남양주1     9
# 421  2015  무단횡단사고다발지      경기도 남양주시1     9
# ..    ...        ...            ...   ...
# 532  2015   자전거사고다발지   경기도 부천시 원미구2     9
# 531  2015   자전거사고다발지   경기도 부천시 원미구1    13
# 530  2015   자전거사고다발지   경기도 부천시 소사구1     5
# 541  2015   자전거사고다발지  경기도 부천시 원미구12     6
# 999  2014   자전거사고다발지   경기도 수원시 영통구2     4
#
# [1000 rows x 4 columns]

# %%
(
    df[['사고년도','사고유형구분','시도시군구명','발생건수']]
.sort_values('사고유형구분',ascending=False)
)
# Out:
#      사고년도     사고유형구분         시도시군구명  발생건수
# 500  2016   자전거사고다발지   경기도 부천시 원미구6     5
# 564  2014   자전거사고다발지  경기도 부천시 원미구14     5
# 562  2014   자전거사고다발지  경기도 부천시 원미구12     5
# 561  2014   자전거사고다발지  경기도 부천시 원미구11     6
# 560  2014   자전거사고다발지  경기도 부천시 원미구10     7
# ..    ...        ...            ...   ...
# 582  2013  무단횡단사고다발지       경기 부천오정4     4
# 581  2013  무단횡단사고다발지       경기 부천오정3     4
# 580  2013  무단횡단사고다발지       경기 부천원미1     6
# 579  2013  무단횡단사고다발지       경기 부천오정1     6
# 290  2012  무단횡단사고다발지         경기 구리1     4
#
# [1000 rows x 4 columns]

# %% [markdown]
#  ### value_count 이용
# #### 한건의 사고에서 다치거나 사망하는 인원수 확인

# %%
df['부상자수'].value_counts() #한건의 사고에서 부상자수가 가장 많이 발생하는경우는 4명
# Out:
# 0    718
# 1    207
# 2     56
# 3     17
# 4      2
# Name: 부상자수, dtype: int64

# %%
df['사망자수'].value_counts() #4명
# Out:
# 0    796
# 1    176
# 2     28
# Name: 사망자수, dtype: int64

# %%
df['경상자수'].value_counts() #10명
# Out:
# 1     244
# 2     243
# 3     167
# 0     162
# 4      96
# 5      60
# 6      20
# 7       5
# 10      2
# 8       1
# Name: 경상자수, dtype: int64

# %%
df['중상자수'].value_counts() #22명
# Out:
# 2     248
# 1     247
# 3     224
# 4     109
# 0     100
# 5      36
# 6      16
# 7       9
# 8       7
# 12      2
# 10      1
# 9       1
# Name: 중상자수, dtype: int64

# %%
df['사상자수'].value_counts() #사상자:사망자+부상자+경상자+중상자를 다 합친 값 
                              #한건의 사고에서 가장 많은 사상자는 26명이다.
# Out:
# 4     280
# 5     210
# 3     187
# 6     100
# 7      78
# 8      48
# 2      32
# 9      28
# 11     11
# 10      9
# 13      6
# 14      3
# 12      3
# 1       2
# 16      1
# 15      1
# 20      1
# Name: 사상자수, dtype: int64

# %% [markdown]
# ### groupby 이용

# %%
(
df
.groupby('시군명')
.agg({'발생건수':'sum'})
)  #시군명으로 보았을때 수원시가 가장 많은것을 알수있다.
# Out:
#       발생건수
# 시군명
# 가평군     38
# 고양시    745
# 과천시     32
# 광명시    249
# 광주시    126
# 구리시    172
# 군포시    177
# 김포시    144
# 남양주시   304
# 동두천시   102
# 부천시    915
# 성남시    854
# 수원시    884

# %%
(
df
.groupby('사고년도')
.agg({'발생건수':'sum'})
)
# Out:
#       발생건수
# 사고년도
# 2012   758
# 2013   553
# 2014   671
# 2015   833
# 2016   559
# 2017   398
# 2018   420
# 2019   273
# 2020   277

# %%
df['시도시군구명'].value_counts().head() #수원시 안에서 가장 많은 사고가 발생하지만 구에서는 단원구1에서 가장 많은 사고가 일어남
# Out:
# 경기도 광명시1         27
# 경기도 성남시 중원구1     26
# 경기도 남양주시1        24
# 경기도 고양시 일산서구1    20
# 경기도 군포시1         20
# Name: 시도시군구명, dtype: int64

# %%
df['사고지역위치명'].value_counts().head(5) #가장 많이 발생한 위치명
# Out:
# 경기도 광명시 광명동(광명사거리 부근)          8
# 경기도 고양시 일산서구 주엽동(주엽역사거리 부근)    5
# 경기도 성남시 중원구 상대원동(상대원시장앞 부근)    5
# 경기도 수원시 영통구 매탄동(법원사거리 부근)      5
# 경기도 수원시 장안구 영화동(장안문로터리 부근)     4
# Name: 사고지역위치명, dtype: int64
